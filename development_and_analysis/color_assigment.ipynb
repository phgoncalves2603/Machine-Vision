# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
from sklearn.cluster import KMeans

# %%
image_path = "../output_videos\cropped_img.jpg"
image = cv2.imread(image_path)
image = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# <>:1: SyntaxWarning: invalid escape sequence '\c'
# C:\Users\guigu\AppData\Local\Temp\ipykernel_23464\2115407429.py:1: SyntaxWarning: invalid escape sequence '\c'
#   image_path = "../output_videos\cropped_img.jpg"

# %%
plt.imshow(image)
plt.show()

# %%
top = image[0:int(image.shape[0]/2),:]
plt.imshow(top)
plt.show()

# %%
image_2d=top.reshape(-1,3)

#k-means
kmeans = KMeans(n_clusters=2, random_state=0).fit(image_2d)

labels = kmeans.labels_

clustered_image = labels.reshape(top.shape[0], top.shape[1])

plt.imshow(clustered_image)
plt.show()

# %%
corner_cluster = [clustered_image[0,0],clustered_image[0,-1], clustered_image[-1,-1]]
non_player = max(set(corner_cluster), key= corner_cluster.count)
print(non_player)
player = 1-non_player
print(player)
# Out:
# 1
# 0

# %%
kmeans.cluster_centers_[player]
# Out:
# array([171.        , 235.38389262, 142.37718121])
